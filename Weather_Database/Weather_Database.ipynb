# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 753

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | ushuaia
# Processing Record 2 of the Set 1 | severo-kurilsk
# Processing Record 3 of the Set 1 | barra patuca
# Processing Record 4 of the Set 1 | nantucket
# Processing Record 5 of the Set 1 | kodiak
# Processing Record 6 of the Set 1 | peterhead
# Processing Record 7 of the Set 1 | souillac
# Processing Record 8 of the Set 1 | adrar
# Processing Record 9 of the Set 1 | ponta do sol
# Processing Record 10 of the Set 1 | margate
# Processing Record 11 of the Set 1 | tuktoyaktuk
# Processing Record 12 of the Set 1 | yumen
# Processing Record 13 of the Set 1 | yeniseysk
# Processing Record 14 of the Set 1 | ventspils
# Processing Record 15 of the Set 1 | arraial do cabo
# Processing Record 16 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of the Set 1 | byron bay
# Processing Record 18 of the Set 1 | busselton
# Processing Record 19 of the Set 1 | qaanaaq
# Processing Record 20 of the Set 1 | udachnyy
# Processing Record 21 of the Set 1 | cherskiy
# Processing Record 22 of the Set 1 | khani
# Processing Record 23 of the Set 1 | hun
# Processing Record 24 of the Set 1 | tiksi
# Processing Record 25 of the Set 1 | mnogovershinnyy
# Processing Record 26 of the Set 1 | georgetown
# Processing Record 27 of the Set 1 | manado
# Processing Record 28 of the Set 1 | east london
# Processing Record 29 of the Set 1 | umm lajj
# Processing Record 30 of the Set 1 | faanui
# Processing Record 31 of the Set 1 | vaini
# Processing Record 32 of the Set 1 | muros
# Processing Record 33 of the Set 1 | belushya guba
# Processing Record 34 of the Set 1 | doha
# Processing Record 35 of the Set 1 | pevek
# Processing Record 36 of the Set 1 | arlit
# Processing Record 37 of the Set 1 | tengzhou
# Processing Record 38 of the Set 1 | punta arenas
# Processing Record 39 of the Set 1 | kayseri
# Processing Record 40 of the Set 1 | ucluelet
# Processing Record 41 of the Set 1 | pokhara
# Processing Record 42 of the Set 1 | barrow
# Processing Record 43 of the Set 1 | fortuna
# Processing Record 44 of the Set 1 | lebu
# Processing Record 45 of the Set 1 | biak
# Processing Record 46 of the Set 1 | lata
# Processing Record 47 of the Set 1 | gurupa
# Processing Record 48 of the Set 1 | prince george
# Processing Record 49 of the Set 1 | kavieng
# Processing Record 50 of the Set 1 | isangel
# Processing Record 1 of the Set 2 | palana
# Processing Record 2 of the Set 2 | geraldton
# Processing Record 3 of the Set 2 | morwell
# Processing Record 4 of the Set 2 | rikitea
# Processing Record 5 of the Set 2 | yelovo
# Processing Record 6 of the Set 2 | charlestown
# Processing Record 7 of the Set 2 | albany
# Processing Record 8 of the Set 2 | codrington
# Processing Record 9 of the Set 2 | butaritari
# Processing Record 10 of the Set 2 | cape town
# Processing Record 11 of the Set 2 | kaitangata
# Processing Record 12 of the Set 2 | garowe
# Processing Record 13 of the Set 2 | vestmanna
# Processing Record 14 of the Set 2 | khatanga
# Processing Record 15 of the Set 2 | tambovka
# Processing Record 16 of the Set 2 | ancud
# Processing Record 17 of the Set 2 | port elizabeth
# Processing Record 18 of the Set 2 | saleaula
# City not found. Skipping...
# Processing Record 19 of the Set 2 | saint-leu
# Processing Record 20 of the Set 2 | alofi
# Processing Record 21 of the Set 2 | new norfolk
# Processing Record 22 of the Set 2 | norman wells
# Processing Record 23 of the Set 2 | hrymayliv
# Processing Record 24 of the Set 2 | mataura
# Processing Record 25 of the Set 2 | nikolskoye
# Processing Record 26 of the Set 2 | hobart
# Processing Record 27 of the Set 2 | mogadishu
# Processing Record 28 of the Set 2 | atuona
# Processing Record 29 of the Set 2 | te anau
# Processing Record 30 of the Set 2 | los llanos de aridane
# Processing Record 31 of the Set 2 | hirara
# Processing Record 32 of the Set 2 | saint-philippe
# Processing Record 33 of the Set 2 | red bluff
# Processing Record 34 of the Set 2 | senanga
# Processing Record 35 of the Set 2 | mys shmidta
# Processing Record 36 of the Set 2 | chuy
# Processing Record 37 of the Set 2 | praia
# Processing Record 38 of the Set 2 | hobyo
# Processing Record 39 of the Set 2 | bluff
# Processing Record 40 of the Set 2 | kununurra
# Processing Record 41 of the Set 2 | fevralsk
# Processing Record 42 of the Set 2 | sobolevo
# Processing Record 43 of the Set 2 | hithadhoo
# Processing Record 44 of the Set 2 | kalmunai
# Processing Record 45 of the Set 2 | sentyabrskiy
# Processing Record 46 of the Set 2 | salalah
# Processing Record 47 of the Set 2 | ullapool
# Processing Record 48 of the Set 2 | avarua
# Processing Record 49 of the Set 2 | grand river south east
# Processing Record 50 of the Set 2 | illoqqortoormiut
# Processing Record 1 of the Set 3 | ahipara
# Processing Record 2 of the Set 3 | tasiilaq
# Processing Record 3 of the Set 3 | shubarkuduk
# Processing Record 4 of the Set 3 | porto novo
# Processing Record 5 of the Set 3 | vila velha
# Processing Record 6 of the Set 3 | hilo
# Processing Record 7 of the Set 3 | labutta
# City not found. Skipping...
# Processing Record 8 of the Set 3 | rawannawi
# Processing Record 9 of the Set 3 | dikson
# Processing Record 10 of the Set 3 | nepa nagar
# Processing Record 11 of the Set 3 | rudnichnyy
# Processing Record 12 of the Set 3 | moose factory
# Processing Record 13 of the Set 3 | asayita
# City not found. Skipping...
# Processing Record 14 of the Set 3 | tautira
# Processing Record 15 of the Set 3 | alugan
# Processing Record 16 of the Set 3 | rio grande
# Processing Record 17 of the Set 3 | thompson
# Processing Record 18 of the Set 3 | novita
# Processing Record 19 of the Set 3 | hami
# Processing Record 20 of the Set 3 | la sarre
# Processing Record 21 of the Set 3 | beringovskiy
# Processing Record 22 of the Set 3 | kathmandu
# Processing Record 23 of the Set 3 | bengkulu
# Processing Record 24 of the Set 3 | mar del plata
# Processing Record 25 of the Set 3 | ruatoria
# Processing Record 26 of the Set 3 | acapulco
# Processing Record 27 of the Set 3 | ostrovnoy
# Processing Record 28 of the Set 3 | richards bay
# Processing Record 29 of the Set 3 | kapaa
# Processing Record 30 of the Set 3 | yuzhno-yeniseyskiy
# Processing Record 31 of the Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of the Set 3 | big spring
# Processing Record 33 of the Set 3 | tabiauea
# Processing Record 34 of the Set 3 | torbay
# Processing Record 35 of the Set 3 | solsvik
# City not found. Skipping...
# Processing Record 36 of the Set 3 | ternate
# Processing Record 37 of the Set 3 | severomorsk
# Processing Record 38 of the Set 3 | pochutla
# Processing Record 39 of the Set 3 | saint-pierre
# Processing Record 40 of the Set 3 | laguna
# Processing Record 41 of the Set 3 | balclutha
# Processing Record 42 of the Set 3 | almeirim
# Processing Record 43 of the Set 3 | puerto ayora
# Processing Record 44 of the Set 3 | provideniya
# Processing Record 45 of the Set 3 | carnarvon
# Processing Record 46 of the Set 3 | clyde river
# Processing Record 47 of the Set 3 | kilindoni
# Processing Record 48 of the Set 3 | port alfred
# Processing Record 49 of the Set 3 | great yarmouth
# Processing Record 50 of the Set 3 | hassleholm
# Processing Record 1 of the Set 4 | lagoa
# Processing Record 2 of the Set 4 | kendari
# Processing Record 3 of the Set 4 | ruyigi
# Processing Record 4 of the Set 4 | jamestown
# Processing Record 5 of the Set 4 | atar
# Processing Record 6 of the Set 4 | meyungs
# City not found. Skipping...
# Processing Record 7 of the Set 4 | sterling
# Processing Record 8 of the Set 4 | meulaboh
# Processing Record 9 of the Set 4 | nanortalik
# Processing Record 10 of the Set 4 | port macquarie
# Processing Record 11 of the Set 4 | tarko-sale
# Processing Record 12 of the Set 4 | anadyr
# Processing Record 13 of the Set 4 | neuquen
# Processing Record 14 of the Set 4 | lasa
# Processing Record 15 of the Set 4 | solovetskiy
# Processing Record 16 of the Set 4 | saint george
# Processing Record 17 of the Set 4 | zhirnovsk
# Processing Record 18 of the Set 4 | shimoda
# Processing Record 19 of the Set 4 | miraflores
# Processing Record 20 of the Set 4 | chokurdakh
# Processing Record 21 of the Set 4 | brae
# Processing Record 22 of the Set 4 | reyes
# Processing Record 23 of the Set 4 | karachi
# Processing Record 24 of the Set 4 | port hardy
# Processing Record 25 of the Set 4 | aklavik
# Processing Record 26 of the Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 27 of the Set 4 | baruun-urt
# Processing Record 28 of the Set 4 | bambous virieux
# Processing Record 29 of the Set 4 | ust-tarka
# Processing Record 30 of the Set 4 | yellowknife
# Processing Record 31 of the Set 4 | aswan
# Processing Record 32 of the Set 4 | tayoltita
# Processing Record 33 of the Set 4 | san patricio
# Processing Record 34 of the Set 4 | srednekolymsk
# Processing Record 35 of the Set 4 | nemuro
# Processing Record 36 of the Set 4 | port lincoln
# Processing Record 37 of the Set 4 | samusu
# City not found. Skipping...
# Processing Record 38 of the Set 4 | zhangye
# Processing Record 39 of the Set 4 | tabialan
# Processing Record 40 of the Set 4 | ribeira grande
# Processing Record 41 of the Set 4 | matamoros
# Processing Record 42 of the Set 4 | kristinehamn
# Processing Record 43 of the Set 4 | carutapera
# Processing Record 44 of the Set 4 | nalut
# Processing Record 45 of the Set 4 | marawi
# Processing Record 46 of the Set 4 | ridgecrest
# Processing Record 47 of the Set 4 | dombarovskiy
# Processing Record 48 of the Set 4 | emerald
# Processing Record 49 of the Set 4 | talnakh
# Processing Record 50 of the Set 4 | mujiayingzi
# Processing Record 1 of the Set 5 | nueve de julio
# Processing Record 2 of the Set 5 | leningradskiy
# Processing Record 3 of the Set 5 | padang
# Processing Record 4 of the Set 5 | qaqortoq
# Processing Record 5 of the Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 6 of the Set 5 | nyurba
# Processing Record 7 of the Set 5 | lorengau
# Processing Record 8 of the Set 5 | santa rosa
# Processing Record 9 of the Set 5 | bosaso
# Processing Record 10 of the Set 5 | marcona
# City not found. Skipping...
# Processing Record 11 of the Set 5 | coihaique
# Processing Record 12 of the Set 5 | longyearbyen
# City not found. Skipping...
# Processing Record 13 of the Set 5 | stokmarknes
# City not found. Skipping...
# Processing Record 14 of the Set 5 | virginia beach
# Processing Record 15 of the Set 5 | hermanus
# Processing Record 16 of the Set 5 | nizhneyansk
# Processing Record 17 of the Set 5 | port-gentil
# Processing Record 18 of the Set 5 | zhigansk
# Processing Record 19 of the Set 5 | victoria
# Processing Record 20 of the Set 5 | cidreira
# Processing Record 21 of the Set 5 | maloshuyka
# Processing Record 22 of the Set 5 | lac du bonnet
# Processing Record 23 of the Set 5 | brezno
# Processing Record 24 of the Set 5 | pisco
# City not found. Skipping...
# Processing Record 25 of the Set 5 | saskylakh
# Processing Record 26 of the Set 5 | kletskaya
# Processing Record 27 of the Set 5 | kansanshi
# Processing Record 28 of the Set 5 | vestmannaeyjar
# Processing Record 29 of the Set 5 | kitimat
# Processing Record 30 of the Set 5 | murud
# Processing Record 31 of the Set 5 | araouane
# Processing Record 32 of the Set 5 | yar-sale
# Processing Record 33 of the Set 5 | coahuayana
# Processing Record 34 of the Set 5 | nago
# Processing Record 35 of the Set 5 | vallenar
# Processing Record 36 of the Set 5 | katsuura
# Processing Record 37 of the Set 5 | wajima
# Processing Record 38 of the Set 5 | berlevag
# City not found. Skipping...
# Processing Record 39 of the Set 5 | omboue
# Processing Record 40 of the Set 5 | tuatapere
# Processing Record 41 of the Set 5 | follebu
# City not found. Skipping...
# Processing Record 42 of the Set 5 | mokrousovo
# Processing Record 43 of the Set 5 | turukhansk
# Processing Record 44 of the Set 5 | port blair
# Processing Record 45 of the Set 5 | kyabe
# Processing Record 46 of the Set 5 | hasaki
# Processing Record 47 of the Set 5 | coquimbo
# Processing Record 48 of the Set 5 | upernavik
# Processing Record 49 of the Set 5 | narsaq
# Processing Record 50 of the Set 5 | namibe
# Processing Record 1 of the Set 6 | san cristobal
# Processing Record 2 of the Set 6 | henties bay
# Processing Record 3 of the Set 6 | esperance
# Processing Record 4 of the Set 6 | nong phai
# Processing Record 5 of the Set 6 | shadegan
# Processing Record 6 of the Set 6 | mullaitivu
# Processing Record 7 of the Set 6 | husavik
# Processing Record 8 of the Set 6 | kokopo
# Processing Record 9 of the Set 6 | bredasdorp
# Processing Record 10 of the Set 6 | buqayq
# Processing Record 11 of the Set 6 | gambela
# City not found. Skipping...
# Processing Record 12 of the Set 6 | luganville
# Processing Record 13 of the Set 6 | panaba
# Processing Record 14 of the Set 6 | mayskiy
# Processing Record 15 of the Set 6 | powell river
# Processing Record 16 of the Set 6 | uige
# Processing Record 17 of the Set 6 | muisne
# Processing Record 18 of the Set 6 | cayenne
# Processing Record 19 of the Set 6 | veraval
# Processing Record 20 of the Set 6 | dwarka
# Processing Record 21 of the Set 6 | nelson bay
# Processing Record 22 of the Set 6 | maceio
# Processing Record 23 of the Set 6 | novikovo
# Processing Record 24 of the Set 6 | sencha
# Processing Record 25 of the Set 6 | longlac
# Processing Record 26 of the Set 6 | touros
# Processing Record 27 of the Set 6 | usogorsk
# Processing Record 28 of the Set 6 | masuri
# Processing Record 29 of the Set 6 | chengde
# Processing Record 30 of the Set 6 | bethel
# Processing Record 31 of the Set 6 | ambulu
# Processing Record 32 of the Set 6 | porto belo
# Processing Record 33 of the Set 6 | kahului
# Processing Record 34 of the Set 6 | the valley
# Processing Record 35 of the Set 6 | jacqueville
# Processing Record 36 of the Set 6 | castro
# Processing Record 37 of the Set 6 | roebourne
# Processing Record 38 of the Set 6 | gilgit
# Processing Record 39 of the Set 6 | chunoyar
# Processing Record 40 of the Set 6 | maghama
# Processing Record 41 of the Set 6 | morros
# Processing Record 42 of the Set 6 | berck
# Processing Record 43 of the Set 6 | clarence town
# Processing Record 44 of the Set 6 | san blas
# Processing Record 45 of the Set 6 | dakar
# Processing Record 46 of the Set 6 | aykhal
# Processing Record 47 of the Set 6 | luwuk
# Processing Record 48 of the Set 6 | plettenberg bay
# Processing Record 49 of the Set 6 | araria
# Processing Record 50 of the Set 6 | samarai
# Processing Record 1 of the Set 7 | sabang
# Processing Record 2 of the Set 7 | huangyan
# Processing Record 3 of the Set 7 | baykit
# Processing Record 4 of the Set 7 | mareeba
# Processing Record 5 of the Set 7 | vao
# Processing Record 6 of the Set 7 | maracaibo
# Processing Record 7 of the Set 7 | kaka
# Processing Record 8 of the Set 7 | tambopata
# City not found. Skipping...
# Processing Record 9 of the Set 7 | north bend
# Processing Record 10 of the Set 7 | noyabrsk
# Processing Record 11 of the Set 7 | solotvyn
# Processing Record 12 of the Set 7 | talcher
# Processing Record 13 of the Set 7 | iqaluit
# Processing Record 14 of the Set 7 | dholka
# Processing Record 15 of the Set 7 | la ronge
# Processing Record 16 of the Set 7 | bilibino
# Processing Record 17 of the Set 7 | mount isa
# Processing Record 18 of the Set 7 | bambanglipuro
# Processing Record 19 of the Set 7 | chapais
# Processing Record 20 of the Set 7 | yinchuan
# Processing Record 21 of the Set 7 | trikerion
# City not found. Skipping...
# Processing Record 22 of the Set 7 | dieppe
# Processing Record 23 of the Set 7 | sistranda
# City not found. Skipping...
# Processing Record 24 of the Set 7 | pulandian
# Processing Record 25 of the Set 7 | nara
# Processing Record 26 of the Set 7 | ugoofaaru
# Processing Record 27 of the Set 7 | okhotsk
# Processing Record 28 of the Set 7 | cabo san lucas
# Processing Record 29 of the Set 7 | kayerkan
# Processing Record 30 of the Set 7 | vardo
# City not found. Skipping...
# Processing Record 31 of the Set 7 | wuxue
# Processing Record 32 of the Set 7 | chaman
# Processing Record 33 of the Set 7 | kosgi
# Processing Record 34 of the Set 7 | luderitz
# Processing Record 35 of the Set 7 | bathsheba
# Processing Record 36 of the Set 7 | karpathos
# City not found. Skipping...
# Processing Record 37 of the Set 7 | harper
# Processing Record 38 of the Set 7 | kedrovyy
# Processing Record 39 of the Set 7 | morehead
# Processing Record 40 of the Set 7 | amderma
# Processing Record 41 of the Set 7 | yulara
# Processing Record 42 of the Set 7 | flin flon
# Processing Record 43 of the Set 7 | muravlenko
# Processing Record 44 of the Set 7 | petropavlovsk-kamchatskiy
# Processing Record 45 of the Set 7 | talen
# Processing Record 46 of the Set 7 | escuinapa
# Processing Record 47 of the Set 7 | altamira
# Processing Record 48 of the Set 7 | dingle
# Processing Record 49 of the Set 7 | boksitogorsk
# Processing Record 50 of the Set 7 | krapivinskiy
# Processing Record 1 of the Set 8 | camacha
# Processing Record 2 of the Set 8 | constitucion
# Processing Record 3 of the Set 8 | fort saint john
# Processing Record 4 of the Set 8 | zeya
# Processing Record 5 of the Set 8 | makakilo city
# Processing Record 6 of the Set 8 | deputatskiy
# Processing Record 7 of the Set 8 | pavilosta
# Processing Record 8 of the Set 8 | gusau
# Processing Record 9 of the Set 8 | borba
# Processing Record 10 of the Set 8 | lolua
# City not found. Skipping...
# Processing Record 11 of the Set 8 | cockburn town
# Processing Record 12 of the Set 8 | khandyga
# Processing Record 13 of the Set 8 | brokopondo
# Processing Record 14 of the Set 8 | matara
# Processing Record 15 of the Set 8 | armacao dos buzios
# Processing Record 16 of the Set 8 | suluq
# Processing Record 17 of the Set 8 | brekstad
# City not found. Skipping...
# Processing Record 18 of the Set 8 | carndonagh
# Processing Record 19 of the Set 8 | vilyuysk
# Processing Record 20 of the Set 8 | igarka
# Processing Record 21 of the Set 8 | kyzyl-suu
# Processing Record 22 of the Set 8 | roald
# City not found. Skipping...
# Processing Record 23 of the Set 8 | salamina
# Processing Record 24 of the Set 8 | dolbeau
# Processing Record 25 of the Set 8 | caruray
# Processing Record 26 of the Set 8 | airai
# City not found. Skipping...
# Processing Record 27 of the Set 8 | jucas
# Processing Record 28 of the Set 8 | djibo
# Processing Record 29 of the Set 8 | hay river
# Processing Record 30 of the Set 8 | honiara
# Processing Record 31 of the Set 8 | kavaratti
# Processing Record 32 of the Set 8 | hvide sande
# Processing Record 33 of the Set 8 | baishishan
# Processing Record 34 of the Set 8 | torrijos
# Processing Record 35 of the Set 8 | ikalamavony
# City not found. Skipping...
# Processing Record 36 of the Set 8 | aasiaat
# Processing Record 37 of the Set 8 | port hedland
# Processing Record 38 of the Set 8 | attawapiskat
# Processing Record 39 of the Set 8 | luau
# Processing Record 40 of the Set 8 | havre-saint-pierre
# Processing Record 41 of the Set 8 | sisimiut
# Processing Record 42 of the Set 8 | sinnamary
# Processing Record 43 of the Set 8 | klaksvik
# Processing Record 44 of the Set 8 | albuquerque
# Processing Record 45 of the Set 8 | ranong
# Processing Record 46 of the Set 8 | varzea da palma
# Processing Record 47 of the Set 8 | buala
# Processing Record 48 of the Set 8 | nizwa
# Processing Record 49 of the Set 8 | paamiut
# Processing Record 50 of the Set 8 | misratah
# Processing Record 1 of the Set 9 | goderich
# Processing Record 2 of the Set 9 | antofagasta
# Processing Record 3 of the Set 9 | saint-jovite
# Processing Record 4 of the Set 9 | egvekinot
# Processing Record 5 of the Set 9 | black forest
# Processing Record 6 of the Set 9 | tornio
# Processing Record 7 of the Set 9 | acajutla
# Processing Record 8 of the Set 9 | mayumba
# Processing Record 9 of the Set 9 | broome
# Processing Record 10 of the Set 9 | potosi
# Processing Record 11 of the Set 9 | pacific grove
# Processing Record 12 of the Set 9 | paracuru
# Processing Record 13 of the Set 9 | rawson
# Processing Record 14 of the Set 9 | nabire
# Processing Record 15 of the Set 9 | olafsvik
# Processing Record 16 of the Set 9 | poykovskiy
# Processing Record 17 of the Set 9 | tanshui
# City not found. Skipping...
# Processing Record 18 of the Set 9 | novokizhinginsk
# Processing Record 19 of the Set 9 | esso
# Processing Record 20 of the Set 9 | vila franca do campo
# Processing Record 21 of the Set 9 | ondorhaan
# Processing Record 22 of the Set 9 | coffs harbour
# Processing Record 23 of the Set 9 | caravelas
# Processing Record 24 of the Set 9 | victor harbor
# Processing Record 25 of the Set 9 | bay roberts
# Processing Record 26 of the Set 9 | kruisfontein
# Processing Record 27 of the Set 9 | paita
# City not found. Skipping...
# Processing Record 28 of the Set 9 | malwan
# Processing Record 29 of the Set 9 | aras
# City not found. Skipping...
# Processing Record 30 of the Set 9 | tual
# Processing Record 31 of the Set 9 | calabozo
# Processing Record 32 of the Set 9 | calvinia
# Processing Record 33 of the Set 9 | torbat-e jam
# Processing Record 34 of the Set 9 | wlodawa
# Processing Record 35 of the Set 9 | singapore
# Processing Record 36 of the Set 9 | konevo
# Processing Record 37 of the Set 9 | kaduqli
# Processing Record 38 of the Set 9 | sorvag
# Processing Record 39 of the Set 9 | zanesville
# Processing Record 40 of the Set 9 | alta floresta
# Processing Record 41 of the Set 9 | college
# Processing Record 42 of the Set 9 | brownwood
# Processing Record 43 of the Set 9 | marsh harbour
# Processing Record 44 of the Set 9 | cuorgne
# Processing Record 45 of the Set 9 | batagay-alyta
# Processing Record 46 of the Set 9 | tocopilla
# Processing Record 47 of the Set 9 | inhambane
# Processing Record 48 of the Set 9 | saint-francois
# Processing Record 49 of the Set 9 | jalu
# Processing Record 50 of the Set 9 | chanasma
# Processing Record 1 of the Set 10 | toro
# Processing Record 2 of the Set 10 | kearney
# Processing Record 3 of the Set 10 | pierre
# Processing Record 4 of the Set 10 | tumannyy
# Processing Record 5 of the Set 10 | pauini
# Processing Record 6 of the Set 10 | chicama
# City not found. Skipping...
# Processing Record 7 of the Set 10 | dunedin
# Processing Record 8 of the Set 10 | kijang
# Processing Record 9 of the Set 10 | saint-pierre
# Processing Record 10 of the Set 10 | fujin
# Processing Record 11 of the Set 10 | booue
# Processing Record 12 of the Set 10 | ilulissat
# Processing Record 13 of the Set 10 | pekalongan
# Processing Record 14 of the Set 10 | dumas
# Processing Record 15 of the Set 10 | kabanjahe
# Processing Record 16 of the Set 10 | myaundzha
# Processing Record 17 of the Set 10 | nong khai
# Processing Record 18 of the Set 10 | lasem
# Processing Record 19 of the Set 10 | mikhaylovsk
# Processing Record 20 of the Set 10 | palafrugell
# Processing Record 21 of the Set 10 | itarema
# Processing Record 22 of the Set 10 | bubaque
# Processing Record 23 of the Set 10 | waw
# Processing Record 24 of the Set 10 | ordzhonikidze
# Processing Record 25 of the Set 10 | teneguiban
# Processing Record 26 of the Set 10 | kenai
# Processing Record 27 of the Set 10 | thinadhoo
# Processing Record 28 of the Set 10 | puerto baquerizo moreno
# Processing Record 29 of the Set 10 | provost
# Processing Record 30 of the Set 10 | buin
# Processing Record 31 of the Set 10 | sitka
# Processing Record 32 of the Set 10 | khash
# Processing Record 33 of the Set 10 | lucea
# Processing Record 34 of the Set 10 | valparaiso
# Processing Record 35 of the Set 10 | karratha
# Processing Record 36 of the Set 10 | whitecourt
# Processing Record 37 of the Set 10 | iquique
# Processing Record 38 of the Set 10 | san quintin
# Processing Record 39 of the Set 10 | japura
# Processing Record 40 of the Set 10 | kroonstad
# Processing Record 41 of the Set 10 | galle
# Processing Record 42 of the Set 10 | alice springs
# Processing Record 43 of the Set 10 | komsomolets
# Processing Record 44 of the Set 10 | sao joao da barra
# Processing Record 45 of the Set 10 | naze
# Processing Record 46 of the Set 10 | cordoba
# Processing Record 47 of the Set 10 | bonthe
# Processing Record 48 of the Set 10 | celestun
# Processing Record 49 of the Set 10 | kulunda
# Processing Record 50 of the Set 10 | sioux lookout
# Processing Record 1 of the Set 11 | sumiswald
# Processing Record 2 of the Set 11 | umzimvubu
# Processing Record 3 of the Set 11 | nouakchott
# Processing Record 4 of the Set 11 | kloulklubed
# City not found. Skipping...
# Processing Record 5 of the Set 11 | burica
# City not found. Skipping...
# Processing Record 6 of the Set 11 | qeshm
# Processing Record 7 of the Set 11 | lannion
# Processing Record 8 of the Set 11 | myatlevo
# Processing Record 9 of the Set 11 | beloha
# Processing Record 10 of the Set 11 | lazaro cardenas
# Processing Record 11 of the Set 11 | madaoua
# Processing Record 12 of the Set 11 | urucara
# Processing Record 13 of the Set 11 | barguzin
# Processing Record 14 of the Set 11 | tucurui
# Processing Record 15 of the Set 11 | bayangol
# Processing Record 16 of the Set 11 | sibiti
# Processing Record 17 of the Set 11 | guerrero negro
# Processing Record 18 of the Set 11 | mgandu
# Processing Record 19 of the Set 11 | quelimane
# Processing Record 20 of the Set 11 | sotnikovo
# Processing Record 21 of the Set 11 | paradwip
# Processing Record 22 of the Set 11 | sechura
# City not found. Skipping...
# Processing Record 23 of the Set 11 | nizhnyaya pavlovka
# Processing Record 24 of the Set 11 | tigil
# Processing Record 25 of the Set 11 | crotone
# Processing Record 26 of the Set 11 | saint-georges
# Processing Record 27 of the Set 11 | kesova gora
# Processing Record 28 of the Set 11 | nguiu
# Processing Record 29 of the Set 11 | filimonovo
# Processing Record 30 of the Set 11 | zachary
# Processing Record 31 of the Set 11 | birecik
# Processing Record 32 of the Set 11 | tessalit
# Processing Record 33 of the Set 11 | kisangani
# Processing Record 34 of the Set 11 | sakakah
# Processing Record 35 of the Set 11 | mangan
# Processing Record 36 of the Set 11 | urusha
# Processing Record 37 of the Set 11 | zhanatas
# Processing Record 38 of the Set 11 | kerouane
# Processing Record 39 of the Set 11 | port antonio
# Processing Record 40 of the Set 11 | lang suan
# Processing Record 41 of the Set 11 | la crosse
# Processing Record 42 of the Set 11 | kutno
# Processing Record 43 of the Set 11 | tacna
# City not found. Skipping...
# Processing Record 44 of the Set 11 | carmen
# Processing Record 45 of the Set 11 | zaragoza
# Processing Record 46 of the Set 11 | rapid valley
# Processing Record 47 of the Set 11 | horni benesov
# Processing Record 48 of the Set 11 | sovetskiy
# Processing Record 49 of the Set 11 | marechal candido rondon
# Processing Record 50 of the Set 11 | areka
# City not found. Skipping...
# Processing Record 1 of the Set 12 | basoko
# Processing Record 2 of the Set 12 | palabuhanratu
# Processing Record 3 of the Set 12 | bedesa
# City not found. Skipping...
# Processing Record 4 of the Set 12 | aflu
# Processing Record 5 of the Set 12 | abha
# Processing Record 6 of the Set 12 | hambantota
# Processing Record 7 of the Set 12 | elbistan
# Processing Record 8 of the Set 12 | parana
# Processing Record 9 of the Set 12 | saint-joseph
# Processing Record 10 of the Set 12 | bergneustadt
# Processing Record 11 of the Set 12 | vurnary
# Processing Record 12 of the Set 12 | wasilla
# Processing Record 13 of the Set 12 | columbus
# Processing Record 14 of the Set 12 | robe
# City not found. Skipping...
# Processing Record 15 of the Set 12 | mormugao
# Processing Record 16 of the Set 12 | glazov
# Processing Record 17 of the Set 12 | port shepstone
# Processing Record 18 of the Set 12 | hayden
# Processing Record 19 of the Set 12 | gubkinskiy
# Processing Record 20 of the Set 12 | mount gambier
# Processing Record 21 of the Set 12 | san vicente de canete
# City not found. Skipping...
# Processing Record 22 of the Set 12 | asau
# City not found. Skipping...
# Processing Record 23 of the Set 12 | araceli
# Processing Record 24 of the Set 12 | sambava
# Processing Record 25 of the Set 12 | skibbereen
# Processing Record 26 of the Set 12 | abu samrah
# Processing Record 27 of the Set 12 | lalitpur
# Processing Record 28 of the Set 12 | scarborough
# Processing Record 29 of the Set 12 | rio gallegos
# Processing Record 30 of the Set 12 | kirakira
# Processing Record 31 of the Set 12 | polyarnyy
# Processing Record 32 of the Set 12 | saint anthony
# Processing Record 33 of the Set 12 | labuhan
# Processing Record 34 of the Set 12 | dali
# Processing Record 35 of the Set 12 | ezhou
# Processing Record 36 of the Set 12 | krasnoselkup
# Processing Record 37 of the Set 12 | melfi
# Processing Record 38 of the Set 12 | camocim
# Processing Record 39 of the Set 12 | aginskoye
# Processing Record 40 of the Set 12 | ilo
# City not found. Skipping...
# Processing Record 41 of the Set 12 | syriam
# Processing Record 42 of the Set 12 | lugazi
# Processing Record 43 of the Set 12 | winslow
# Processing Record 44 of the Set 12 | ponta delgada
# Processing Record 45 of the Set 12 | ingham
# Processing Record 46 of the Set 12 | half moon bay
# Processing Record 47 of the Set 12 | hervey bay
# Processing Record 48 of the Set 12 | macapa
# Processing Record 49 of the Set 12 | gamboma
# Processing Record 50 of the Set 12 | redding
# Processing Record 1 of the Set 13 | fukue
# Processing Record 2 of the Set 13 | tiznit
# Processing Record 3 of the Set 13 | straumen
# City not found. Skipping...
# Processing Record 4 of the Set 13 | simiti
# Processing Record 5 of the Set 13 | comodoro rivadavia
# Processing Record 6 of the Set 13 | amli
# City not found. Skipping...
# Processing Record 7 of the Set 13 | tamandare
# Processing Record 8 of the Set 13 | grass valley
# Processing Record 9 of the Set 13 | askarovo
# Processing Record 10 of the Set 13 | sinop
# Processing Record 11 of the Set 13 | sosnovo-ozerskoye
# Processing Record 12 of the Set 13 | lalmohan
# Processing Record 13 of the Set 13 | chernyakhovsk
# Processing Record 14 of the Set 13 | road town
# Processing Record 15 of the Set 13 | nouadhibou
# Processing Record 16 of the Set 13 | lima
# City not found. Skipping...
# Processing Record 17 of the Set 13 | bansang
# Processing Record 18 of the Set 13 | faya
# Processing Record 19 of the Set 13 | miracatu
# Processing Record 20 of the Set 13 | sao felix do xingu
# Processing Record 21 of the Set 13 | murdochville
# Processing Record 22 of the Set 13 | ketchikan
# Processing Record 23 of the Set 13 | cedar city
# Processing Record 24 of the Set 13 | muzquiz
# Processing Record 25 of the Set 13 | peremyshl
# Processing Record 26 of the Set 13 | great falls
# Processing Record 27 of the Set 13 | angra
# Processing Record 28 of the Set 13 | chabahar
# Processing Record 29 of the Set 13 | vengerovo
# Processing Record 30 of the Set 13 | marzuq
# Processing Record 31 of the Set 13 | chagda
# Processing Record 32 of the Set 13 | mahon
# Processing Record 33 of the Set 13 | dudinka
# Processing Record 34 of the Set 13 | suntar
# Processing Record 35 of the Set 13 | eldorado
# Processing Record 36 of the Set 13 | ruwi
# Processing Record 37 of the Set 13 | katangli
# Processing Record 38 of the Set 13 | myre
# Processing Record 39 of the Set 13 | kangaatsiaq
# Processing Record 40 of the Set 13 | bilma
# Processing Record 41 of the Set 13 | diffa
# Processing Record 42 of the Set 13 | cururupu
# Processing Record 43 of the Set 13 | semnan
# Processing Record 44 of the Set 13 | saldanha
# Processing Record 45 of the Set 13 | faratsiho
# Processing Record 46 of the Set 13 | aguas formosas
# Processing Record 47 of the Set 13 | zhanaozen
# Processing Record 48 of the Set 13 | kwinana
# Processing Record 49 of the Set 13 | pombas
# Processing Record 50 of the Set 13 | santa eulalia del rio
# Processing Record 1 of the Set 14 | fort nelson
# Processing Record 2 of the Set 14 | arica
# Processing Record 3 of the Set 14 | kita
# Processing Record 4 of the Set 14 | imbituba
# Processing Record 5 of the Set 14 | hof
# Processing Record 6 of the Set 14 | mirabad
# Processing Record 7 of the Set 14 | sorong
# Processing Record 8 of the Set 14 | basqal
# Processing Record 9 of the Set 14 | yatou
# Processing Record 10 of the Set 14 | zabaykalsk
# Processing Record 11 of the Set 14 | jabiru
# Processing Record 12 of the Set 14 | moussoro
# Processing Record 13 of the Set 14 | alunis
# Processing Record 14 of the Set 14 | baghmara
# Processing Record 15 of the Set 14 | pangkalanbuun
# Processing Record 16 of the Set 14 | boa vista
# Processing Record 17 of the Set 14 | guerrero
# Processing Record 18 of the Set 14 | cabedelo
# Processing Record 19 of the Set 14 | salinas
# Processing Record 20 of the Set 14 | tyup
# Processing Record 21 of the Set 14 | palatka
# Processing Record 22 of the Set 14 | pitkyaranta
# Processing Record 23 of the Set 14 | pavullo nel frignano
# Processing Record 24 of the Set 14 | schwalmstadt
# Processing Record 25 of the Set 14 | sena madureira
# Processing Record 26 of the Set 14 | burkhala
# Processing Record 27 of the Set 14 | grindavik
# Processing Record 28 of the Set 14 | teknaf
# Processing Record 29 of the Set 14 | moranbah
# Processing Record 30 of the Set 14 | mahebourg
# Processing Record 31 of the Set 14 | toccoa
# Processing Record 32 of the Set 14 | ngunguru
# Processing Record 33 of the Set 14 | fleetwood
# Processing Record 34 of the Set 14 | hamilton
# Processing Record 35 of the Set 14 | dayong
# Processing Record 36 of the Set 14 | yerbogachen
# Processing Record 37 of the Set 14 | katherine
# Processing Record 38 of the Set 14 | lagunas
# City not found. Skipping...
# Processing Record 39 of the Set 14 | hualmay
# City not found. Skipping...
# Processing Record 40 of the Set 14 | seoul
# Processing Record 41 of the Set 14 | carire
# Processing Record 42 of the Set 14 | yaqui
# Processing Record 43 of the Set 14 | carupano
# Processing Record 44 of the Set 14 | bud
# Processing Record 45 of the Set 14 | fasa
# Processing Record 46 of the Set 14 | neiafu
# Processing Record 47 of the Set 14 | jiddah
# Processing Record 48 of the Set 14 | rundu
# Processing Record 49 of the Set 14 | tvoroyri
# Processing Record 50 of the Set 14 | amontada
# Processing Record 1 of the Set 15 | one hundred mile house
# Processing Record 2 of the Set 15 | saint-augustin
# Processing Record 3 of the Set 15 | camapua
# Processing Record 4 of the Set 15 | belousovka
# Processing Record 5 of the Set 15 | namatanai
# Processing Record 6 of the Set 15 | natchez
# Processing Record 7 of the Set 15 | volsk
# Processing Record 8 of the Set 15 | gat
# Processing Record 9 of the Set 15 | najran
# Processing Record 10 of the Set 15 | avera
# Processing Record 11 of the Set 15 | lar
# Processing Record 12 of the Set 15 | kautokeino
# Processing Record 13 of the Set 15 | vidim
# Processing Record 14 of the Set 15 | kichera
# Processing Record 15 of the Set 15 | spas-klepiki
# Processing Record 16 of the Set 15 | manacapuru
# Processing Record 17 of the Set 15 | homer
# Processing Record 18 of the Set 15 | tasbuget
# Processing Record 19 of the Set 15 | oktyabrskiy
# Processing Record 20 of the Set 15 | toliary
# Processing Record 21 of the Set 15 | vanino
# Processing Record 22 of the Set 15 | edinburgh
# Processing Record 23 of the Set 15 | akyab
# Processing Record 24 of the Set 15 | springdale
# Processing Record 25 of the Set 15 | ndjole
# Processing Record 26 of the Set 15 | kawalu
# Processing Record 27 of the Set 15 | oistins
# Processing Record 28 of the Set 15 | gladstone
# Processing Record 29 of the Set 15 | buchanan
# Processing Record 30 of the Set 15 | qasigiannguit
# Processing Record 31 of the Set 15 | bagontapay
# Processing Record 32 of the Set 15 | yurgamysh
# Processing Record 33 of the Set 15 | sundsvall
# Processing Record 34 of the Set 15 | niquero
# Processing Record 35 of the Set 15 | khorramabad
# Processing Record 36 of the Set 15 | mbuguni
# Processing Record 37 of the Set 15 | port hawkesbury
# Processing Record 38 of the Set 15 | ojinaga
# Processing Record 39 of the Set 15 | mustafabad
# Processing Record 40 of the Set 15 | villanueva
# Processing Record 41 of the Set 15 | shush
# Processing Record 42 of the Set 15 | cotonou
# Processing Record 43 of the Set 15 | quatre cocos
# Processing Record 44 of the Set 15 | tilichiki
# Processing Record 45 of the Set 15 | lerwick
# Processing Record 46 of the Set 15 | sangar
# Processing Record 47 of the Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of the Set 15 | salym
# Processing Record 49 of the Set 15 | sur
# Processing Record 50 of the Set 15 | polunochnoye
# Processing Record 1 of the Set 16 | tura
# Processing Record 2 of the Set 16 | leh
# Processing Record 3 of the Set 16 | teguldet
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check number of cities
len(city_data)
# Out:
# 706

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     40.66        75          75
# 1  Severo-Kurilsk      RU  50.6789  156.1250     51.46        79          80
# 2    Barra Patuca      HN  15.8000  -84.2833     81.16        82          86
# 3       Nantucket      US  41.2835  -70.0995     64.09        77           1
# 4          Kodiak      US  41.2835  -70.0995     64.09        77           1
#
#    Wind Speed Current Description
# 0       16.11       broken clouds
# 1       16.37       broken clouds
# 2        6.93     overcast clouds
# 3        6.91           clear sky
# 4        6.91           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
